# %% [markdown]
# MEMORIA
# ### 1. Business case & Data Collection
# 1. ***Business understanding***: Me llevó bastante tiempo decidir el tema de mi EDA, algo que me apasionara tanto que no se me hicieran pesadas las horas de estudio y que resultara útil y divertido a la hora de explicarlo.
# Elegí en un primer momento temas ambientales, GESTION DE RESIDUOS, Y TAMBIÉN LIBROS,VINOS,CAPITULOS DE JUEGO DE TRONOS, EPISODIOS DE LOS SIMPSON. Pero los Dataframe que encontraba sobre estos temas no eran lo bastante completos.
# Finalmente, encontré el tema perfecto...MI DESEO MAS PROFUNDO, COMO EL DE TODOS, ES SER MILLONARIA y pensé, ¿será posible encontrar pautas generales, divertidas y útiles sobre los millonarios que me acerquen algo más a mi sueño?, jajajaja
#
# 2. ***Hipótesis***: Encontré DataFrames suficientes, con muchisima información, y se me plantearon miles de hipotesis (finalmente le di prioridad a 12,que aunque sé que quizás son demasiadas, podrían darme un esbozo bastante bueno de los pasos a seguir para mi primer millón)
# Dado que actualmente, mi Bootcamp e introducción al maravilloso mundo del Data Science no me deja pensar en nada más que en eso, creí conveniente centrar mi hipótesis principal en, ¿qué posibilidades tengo de crear una empresa tecnológica y que hacerme millonaria?
# La hipótesis correcta, sin embargo, debía ser un poco distinta. Tenía que hacer una afirmación y a partir de ahi estudiar mis relativas posibilidades para ello, de modo que surgió:
#
# >hipotesis_final = "La edad y el género de un billonario influye en la probabilidad de tener una empresa tecnológica
#     La preferencia por sectores tecnológicos se relaciona con la edad del billonario y con su género"
#
# QUE DESGRANAMOS EN DOS:
# 1. **HIPOTESIS1** = "Diferentes generaciones podrían tener preferencias distintas en cuanto a tecnologías emergentes. Los billonarios más jóvenes podrían tener una mayor probabilidad de tener empresas tecnológicas debido a su familiaridad con las tendencias actuales."
# 2.  **HIPOTESIS2** = "Podría haber diferencias en la participación en industrias tecnológicas emergentes entre mujeres y hombres billonarios, siendo normalmente la de hombres mayor que la de mujeres"
#
# Si mi primera hipótesis se cumple, conseguiría acercarme un poco a mi búsqueda (pues aún soy joven o eso quiero pensar).
# Si se cumple la segunda... mala cosa, aunque que no es algo que conseguiría desanimarme de cualquier forma.
#
# El resto de hipótesis que me ayudarán y estudiaré (si es que hay tiempo):
# 1. **Hipotesis_2** (para saber en qué industrias debo invertir) = "Algunas industrias, como las tecnológicas o las de finanzas e inversiones, pueden tener una concentración mayor de multimillonarios"
# 2. **Hipotesis_3** (sacando miga a las mujeres millonarias) = "La cantidad de mujeres billonarias que han alcanzado su fortuna a una edad temprana es menor de las que lo han logrado más tarde en la vida y la edad de inicio y la nacionalidad podría influir en la elección de la industria en la que las mujeres billonarias tienen éxito."
# 3. **Hipotesis_4** (¿tengo posibilidades de hacerme rica en España?) = "Los mil millonarios Españoles tienen mas representacion en Forbes en los ultimos diez años"
# 4. **Hipotesis_5** (¿necesito un padrino rico o la lotería?) = "Orígenes de la Riqueza: HEREDADA O GENERADA? Hipótesis: Los multimillonarios pueden haber acumulado riqueza a través de una herencia o por emprendimiento, PERO SON MAS COMUNES LOS MILLONARIOS EMPRENDEDORES"
# 5. **Hipótesis_6** (¿es mejor que me mude a países con alto PIB?) = "El PIB de un país repercute de manera positiva en el número de millonarios del mismo, a mayor PIB, MAYOR CONCENTRACIÓN DE MILLONARIOS"
# 6. **Hipotesis_7** (¿habría que analizar el momento para montar mi empresa?) = "Eventos económicos significativos, como el COVID, podrían influir en la tasa de crecimiento de la fortuna de los billonarios"
# 7. **Hipotesis_8** (por si puedo ser uno de ellos para 2035) = "Aquellos que aparecen en la lista de billonarios de manera consistente (durante mas años seguidos) podrían tener fortunas más estables"
# 8. **Hipotesis_9** (TEORÍA LOCA, soy Tauro, ¿tendré posibilidades de hacerme millonaria?) = "Hipótesis del horóscopo chino de Wealth-X, las personas nacidas en el año del dragón (1940, 1952, 1964, 1976, 1988, 2000, 2012) tienen más probabilidades de acumular riqueza."
#
# 3. ***Adquisición de datos***: Una vez decidido lo importante, tema e hipótesis, nos ponemos manos a la obra y elegimos los datasets que utilizaremos. Aunque no los usaré todos completos, aunque si algunas partes, y el que usaré principalmente será 'all_billionaires_1997_2023.csv' y 'billionaire_list_20yrs.csv', todos los usados son:

# %%
import pandas as pd
# Guardo en variables los datasets y su fuente. 
# De la limpieza de las columnas innecesarias, las Unnamed y el preprocesamiento, me encargo en los notebooks correspondientes
riquitos = pd.read_csv('all_billionaires_1997_2023.csv')
fuente_1 = "https://www.kaggle.com/datasets/guillemservera/forbes-billionaires-1997-2023"

millonetis_20 = pd.read_csv('billionaire_list_20yrs.csv')
fuente_7 = "https://www.kaggle.com/datasets/salimwid/global-billionaire-wealth-and-sources-2002-2023"

evolucion_milmillonarios = pd.read_csv('evolucion_de_los_milmillonarios_y_su_fortuna_en_el_mundo.csv', delimiter=';')
fuente_2 = "https://www.epdata.es/evolucion-milmillonarios-fortuna-mundo/d556bdc0-e9fe-4460-a19f-6616d08cf3c4"

millonarios_por_paises = pd.read_csv('numero_de_millonarios_por_paises.csv', delimiter = ';')
fuente_3 = "https://www.epdata.es/numero-millonarios-paises/4da6669a-d016-4dfb-9d7a-01133aed4e02"

variacion_millonarios = pd.read_csv('variacion_del_numero_de_millonarios_por_paises (1).csv',delimiter = ';')
fuente_4 = "https://www.epdata.es/variacion-numero-millonarios-paises/3489b920-92c2-4fd8-95b8-a2cadf54b83a"

# Los dos siguientes, los mergearemos y nos servirán para ver si PUEDE haber relación entre el PIB de sus países y el numero de millonarios
PIB_anual = pd.read_csv('PIB anual riqueza total/API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064.csv', delimiter = ',')
fuente_5 = "https://datos.bancomundial.org/API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064"

PIB_paises = pd.read_csv('PIB anual riqueza total/Metadata_Country_API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064.csv')
fuente_6 = "https://datos.bancomundial.org/indicador/NY.GDP.MKTP.KD.ZG?end=2022&lang=es&start=1997&view=chart"

# LOS SIGUIENTES SOLO LOS USARE DE REFUERZOS EN ALGUNAS HIPOTESIS Y PARA RECICLAR ALGUNAS COLUMNAS, NO PARA TODAS

forbes_2640 = pd.read_csv('forbes_2640_billionaires.csv')
fuente_9 = "https://www.kaggle.com/datasets/sujalluhar/billionaires-listed-in-forbes"

# %% [markdown]
# 4. ***Calidad***: Una vez decididos los datasets, es fundamental que los datos sean válidos para el análisis, suficientes, que no tengan excesivos missings, ni estén manipulados.
# Hacemos el filtro de cada uno para elegir las partes a usar.
#
#
# ### 2. Data Understanding y Data Cleaning
# 1. **Exploratorio inicial, juntar tablas si procede, eliminar columnas, asegurarnos de que el formato de los datos sea el correcto, missings (null) y outliers**:
# Empezamos a organizar cada una de las tablas, empezando por las 3 más pequeñas:
# * evolucion_milmillonarios = pd.read_csv('evolucion_de_los_milmillonarios_y_su_fortuna_en_el_mundo.csv', delimiter=';')
# fuente_2 = "https://www.epdata.es/evolucion-milmillonarios-fortuna-mundo/d556bdc0-e9fe-4460-a19f-6616d08cf3c4"
#
# * millonarios_por_paises = pd.read_csv('numero_de_millonarios_por_paises.csv', delimiter = ';')
# fuente_3 = "https://www.epdata.es/numero-millonarios-paises/4da6669a-d016-4dfb-9d7a-01133aed4e02"
#
# * variacion_millonarios = pd.read_csv('variacion_del_numero_de_millonarios_por_paises (1).csv',delimiter = ';')
# fuente_4 = "https://www.epdata.es/variacion-numero-millonarios-paises/3489b920-92c2-4fd8-95b8-a2cadf54b83a"
#
#  obteniendo la información básica: número de columnas, de filas, naturaleza de las variables, tipos de los datos y primeros registros.
#
# Eran tablas bastantes limpias, sin nulos y con poco que modificar, sólo para extraer el gráfico.
# Hacemos los cambios convenientes y, tras filtrar los datos necesarios, creamos las primeras gráficas para ellas, y las guardamos para su uso en las hipótesis.
#
# Luego pasamos a los siguientes Dataframe, los dos del PIB, que usaremos para una de las hipótesis:
# * PIB_anual = pd.read_csv('PIB anual riqueza total/API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064.csv', delimiter = ',')
# fuente_5 = "https://datos.bancomundial.org/API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064"
#
# * PIB_paises = pd.read_csv('PIB anual riqueza total/Metadata_Country_API_NY.GDP.MKTP.KD.ZG_DS2_es_csv_v2_6301064.csv')
# fuente_6 = "https://datos.bancomundial.org/indicador/NY.GDP.MKTP.KD.ZG?end=2022&lang=es&start=1997&view=chart"
#
# Tras los análisis iniciales, MEZCLAREMOS AMBOS DATASET DE PIB, PARA TENER EL NOMBRE DEL PAIS Y EL CODIGO, ASI COMO LOS DATOS NUMÉRICOS en un solo DataFrame. Los fusionaremos por Country Code y usaremos tanto las columnas coincidentes como las que no.
# >   union_PIB = pd.merge(PIB_anual,PIB_paises,on='Country Code',how='outer')
#
# Limpiamos, primero filtramos las columnas que usaremos. Tenemos registros del PIB DESDE 1960, pero no podemos ver todas las columnas de modo que usamos el atributo columns, y vemos que tenemos registros hasta 2022.
# Decidimos usar solo los ultimos 10 años (2012 a 2022).
# Teniendo en cuenta para lo que utilizaremos este dataset(comparativa de millonarios y pib de sus paises) y que el resto de columnas son innecesarias, FILTRAREMOS SOLO LAS QUE NECESITAMOS Y renombraré COUNTRY NAME_X, que se llamó asi por el merge, y usaré inplace = True para mantener el nombre.
# Seleccionamos las que necesitamos, las dos primeras y las dieciseis ultimas
# > UNION_PIB = union_PIB2.iloc[:, :2].join(union_PIB2.iloc[:, -16:])
# LAS 4 ULTIMAS NO SON AÑOS, DE MODO QUE NO LAS NECESITO,así que las elimino con drop()
#
# Lo reservaremos para usarlo más tarde.
#
# Revisamos otro de los dataset:
# * forbes_2640 = pd.read_csv('forbes_2640_billionaires.csv')
# fuente_7 = "https://www.kaggle.com/datasets/sujalluhar/billionaires-listed-in-forbes"
#
# Pero no le encontramos utilidad. No nos sale en que fecha se recogen los datos, ni siquiera en la página original, y son pocos registros, de modo que lo descartamos.
#
# Hacemos lo mismo con el siguiente:
# *  estadistica_millonario = pd.read_csv('Billionaires Statistics Dataset')
# fuente_8 = "https://www.kaggle.com/datasets/nelgiriyewithana/billionaires-statistics-dataset", pero tampoco nos resulta útil finalmente por el mismo motivo.
#
# Finalmente, llegamos a nuestros dos Dataframes mas extensos:
# * riquitos_forbes = pd.read_csv('all_billionaires_1997_2023.csv')
# fuente_1 = "https://www.kaggle.com/datasets/guillemservera/forbes-billionaires-1997-2023"
#
# * millonetis_Global_Wealth_Source = pd.read_csv('billionaire_list_20yrs.csv')
# fuente_8 = "https://www.kaggle.com/datasets/salimwid/global-billionaire-wealth-and-sources-2002-2023"
#
# La principal diferencia entre Global Wealth Source ('billionaire_list_20yrs.csv') y Forbes ('all_billionaires_1997_2023.csv') es que el primero se enfoca en la riqueza de los países (millonarios, cobro diario y anual) y el segundo en la riqueza de las personas, pero puedo sacar información que necesito de ambos.
#
# Empezamos con millonetis_Global_Wealth_Source:
# - Eliminamos la columna Unnamed:0 y los duplicados de filas. Sin embargo, hay que tener en cuenta que el mismo nombre está para distintos años y el nombre en los distintos años si queremos mantenerlos. Para conseguirlo, eliminamos duplicados basados en la columna 'NAME', PERO teniendo en cuenta 'Año' y obtenemos estas columnas:
# > Index(['name', 'age', 'gender', 'time', 'permanent_country', 'company',
#        'main_industry', 'countries', 'annual_income', 'daily_income',
#        'birth_year'])
#
# Tomamos la decision de eliminar las columnas con mayor porcentaje de nulos 1.last_name, 8.wealth_source_details, 10.state , 11.headquarters, que además no aportan datos que necesite.
#
# TAMBIEN ELIMINAMOS COLUMNAS QUE FACILITAN LOS MISMOS DATOS (COMO NAME_CLEANED Y NAME Y MAIN INDUSTRY E INDUSTRY,y dado que industry tiene nulos, LA ELEGIMOS PARA ELIMINAR). MANTENEMOS EN UNA PRIMERA CRIBA LAS COLUMNAS GENDER, PERMANENT_COUNTRY Y COMPANY, AUNQUE TIENEN NULOS PERO PUEDE QUE NECESITEMOS ESAS COLUMNAS.
# > columnas_malas = ['last_name', 'wealth_source_details', 'state' , 'headquarters', 'name_cleaned','industry' ]
# > millonetis_Global_Wealth_Source_sinduplicados = millonetis_Global_Wealth_Source_sinduplicados.drop(columns=columnas_malas)
#
# REVISO LAS 3 COLUMNAS CON NULOS QUE NOS QUEDAN, GENDER, PERMANENT_COUNTRY Y COMPANY, para ver si podemos prescindir de alguna más.
#
# 1. Primero en *PERMANENT COUNTRY*, revisamos la columna COUNTRIES también, para ver si tienen relacion y podemos prescindir de la permanent_country
# Comprobamos que  LA COLUMNA countries son las siglas del pais que se define en permanent countries, ASI QUE PODEMOS SERVIRNOS DE ELLA PARA COMPLETAR LOS NULOS
# Filtramos el DataFrame para mostrar solo las filas donde la columna permanent countries tiene valores nulos
# > millonetis_Global_Wealth_Source_sinduplicados.loc[millonetis_Global_Wealth_Source_sinduplicados['permanent_country']].isnull(),'countries'.unique()
# Decidimos en un primer momento, sustituirlos por los valores correspondientes en la columna countries, PERO TENIENDO EN CUENTA QUE UNA VEZ QUE REPRESENTEMOS, SI NOS DAN DATOS RAROS O SIN SENTIDO, LOS ELIMINAREMOS
# > millonetis_Global_Wealth_Source_sinduplicados['permanent_country'].fillna(millonetis_Global_Wealth_Source_sinduplicados['countries'], inplace=True)
#
# 2. Pasamos al siguiente CON NULOS, *COMPANY*:
# Cogemos un ejemplo, Bajaj brothers que está al principio, para ver si todos están vacíos en el dataset original.
# HACEMOS OTRA PRUEBA CON, POR EJEMPLO, RICHARD LI, Y COMPROBAMOS QUE SU EMPRESA NO TIENE NOMBRE EN NINGUN AÑO
# > millonetis_Global_Wealth_Source_sinduplicados[millonetis_Global_Wealth_Source_sinduplicados.name =='Richard Li']
#
# Tras las pruebas preliminares, tenemos dos formas de tratar estos datos. O BIEN ELIMINANDO LAS 3625 FILAS, o bien sustituyendo por DESCONOCIDO, por ejemplo. Aún a riesgo de perder informacion, pero teniendo en cuenta que nuestro volumen de muestreo
# son mas de 31000 entradas, AUNQUE 3500 SEA UN NUMERO SIGNIFICATIVO, preferimos prescindir de ellas, AUNQUE CON IDEA DE PODER VOLVER A ESTE PUNTO Y CAMBIAR DE IDEA SI ES UN ERROR.
#
# > millonetis_Global_Wealth_Source_sinduplicados = millonetis_Global_Wealth_Source_sinduplicados.dropna(subset=['company'])
# >>NOTA: tras hacer las primeras transformaciones, vemos que se han eliminado mas de 11.000 registros entre duplicados y nulos.
# Para recuperar parte de los registros y hacer la muestra mas significativa, volvemos a la eliminación realizada en la columna company,
# y sustituimos en lugar de eliminar (CELDA 26), AUNQUE, IGUAL QUE ANTES, TRAS EL ANALISIS DESCRIPTIVO ES POSIBLE QUE HAYA QUE REPLANTEARSELO.
#
# NOTA: finalmente, hemos decidido no eliminar los datos, para no perder todos esos registros, los sustituiremos por DESCONOCIDO.
# > millonetis_Global_Wealth_Source_sinduplicados['company'].fillna('DESCONOCIDO', inplace=True)
#
# 3. Vamos al ultimo nulo, LA COLUMNA *GENDER*
# > millonetis_Global_Wealth_Source_sinduplicados.gender.isnull().sum() # y son 2780 registros
#
# Como ninguna de las otras columnas nos facilita ningun dato sobre el genero, optamos por eliminar directamente las filas nulas
#
# > millonetis_Global_Wealth_Source_sinduplicados.dropna(subset= 'gender',inplace = True)
#
# HACEMOS UNA ÚLTIMA REVISION, CON LAS COLUMNAS QUE NOS QUEDAN Y QUE SIGNIFICA CADA UNA, y eliminamos daily income y countries pues no me sirven
# para mi análisis.
#
# ### **TABLA VARIABLES FINALES**
# 1. name, nombre, dato cadena objeto
# 2. age, edad, dato int64
# 3. gender, género, dato cadena objeto
# 4. time, fecha de recogida del dato, dato int64. No hay que cambiarlo en un datetime en principio, porque solo es el año.
# 5. permanent_country = país NOMBRE COMPLETO , dato cadena objeto
# 6. company = compañia, dato cadena objeto
# 7. main_industry = industria de negocio (sector), dato cadena objeto
# 8. annual_income = LO QUE RECIBE LA PERSONA EN EL AÑO, INGRESO ANUAL, dato int64
# 9. birth_year = año de nacimiento, dato int64, sería conveniente un cambio a datetime
#
# Ahora que tenemos las variables definidas, nos quedan dos tareas que hacer antes de pasar a los análisis: confirmar el formato de los datos y estudiar los outliers. En principio, no hay que cambiar ningún formato de los datos, todos están en el correcto. Si alguno da error al hacer los análisis, veremos si hay que hacer algún cambio extra.
#
#
# Con respecto al último Dataframe, riquitos_forbes, all_billionaires_1997_2023.csv, tras el análisis preliminar, primeros registros, descripción de variables, empezamos las modificaciones.
# Vemos que tenemos registros desde 1997. Dado que en el otro dataset grande que nos basaremos será desde 2013, decidimos prescindir EN UN PRIMER MOMENTO, de todos los registros anteriores a dicho año.
#
# Eliminamos columnas, tras una primera revision vemos que full name (QUE ADEMAS NO TIENE NINGUN NULO) es la unión de last name y first name, POR LO QUE ESTAS DOS SOBRAN. Tambien eliminamos MONTH, que no usaremos, y aquellas con mas del 50% de nulos, ORGANIZATION_NAME Y POSITION_IN_ORGANIZATION.
#
# > riquitos_forbes_13_23.drop(['last_name','first_name','organization_name','position_in_organization','month'],axis=1, inplace = True)
#
# Empezamos a estudiar las columnas con nulos.
# 1. **'Birth date' y 'age'**:  Tiene 614 nulos, no son muchisimos. Tras un primer análisis, VEMOS QUE VARIOS DE LOS PRIMEROS NULOS QUE APARECEN SON NOMBRES DE ASOCIACIONES, POR LO QUE TIENE SENTIDO QUE NO TENGA EDAD NI FECHA DE CUMPLEAÑOS. Hacemos varias pruebas con distintos registros, y TRAS EL ESTUDIO, NO CREO QUE FUERA ADECUADO ELIMINARLOS DIRECTAMENTE, PUES HE VISTO EN ELLAS UNA PAUTA, QUE LOS QUE TIENEN BIRTH DATE TAMBIEN TIENEN NULOS LA COLUMNA AGE (coinciden ambas columnas, OBVIAMENTE) Y QUE TODOS HAN SIDO FORTUNAS HEREDADAS, DE MODO QUE ME PUEDEN SERVIR PARA MIS HIPOTESIS, ASÍ QUE SUSTITUIMOS LOS NAN POR EL VALOR "DESCONOCIDO" EN COLUMNA AGE Y BIRTH_DAY.
#
# 2. **'Gender'**:  Como en la edad y el dia de nacimiento, los generos indeterminados corresponden en un análisis preliminar a nombres de asociaciones. Sustituimos por INDETERMINADO el género(a la hora de hacer los análisis y gráficas, si vemos que los datos son raros eliminaremos las filas correspondientes)
#
# 3. Para seguir preparando solo los datos que necesitamos, tomamos una nueva decision. Tenemos 3 columnas **country_of_citizenship**,**country_of_residence** y **city_of_residence**. No usaremos las tres para nuestra hipotesis, de modo que hacemos una rapida revision para ver cúal de ellos nos puede aportar información más útil. Buscamos duplicados entre 'country_of_citizenship' y 'country_of_residence'
#
#  > registros_iguales = riquitos_forbes_13_23[riquitos_forbes_13_23.duplicated(subset=['country_of_citizenship', 'country_of_residence'], keep=False)]
#
# Casi todos los registros son iguales, de modo que desechamos el país de residencia, pues para mis hipótesis usaré el de nacimiento,'country_of_citizenship'
# > riquitos_forbes_13_23.drop('country_of_residence',axis = 1,inplace=True)
#
# También decidimos eliminar la ciudad de residencia, pues ninguna de nuestras hipótesis reqiere de esta variable
# > riquitos_forbes_13_23.drop('city_of_residence',axis = 1,inplace=True)
#
# 4. **'BUSINESS_CATEGORY' y 'BUSINESS_INDUSTRIES'**: Sólo tienen 3 registros nulos, comprobamos cuales.
# > filtro_nulos_BUSINESS_CATEGORY_industries = riquitos_forbes_13_23['business_category'].isnull()
# nulos_BUSINESS_CATEGORY_industries = riquitos_forbes_13_23[filtro_nulos_BUSINESS_CATEGORY_industries]
#
# Comprobamos que los 3 registros nulos DE AMBOS SE COMPARTEN, Laurene Powell Jobs & family. Revisamos solo este en dataframe original.
# > riquitos_forbes_13_23[riquitos_forbes_13_23['full_name'] == 'Laurene Powell Jobs & family']
#
# En otros años, están rellenos ambos campos con TECHNOLOGY, DE MODO QUE LOS RELLENAMOS CON ESE DATO
# > riquitos_forbes_13_23[['business_category', 'business_industries']] = riquitos_forbes_13_23[['business_category', 'business_industries']].fillna('Technology')
#
# 5. **'WEALTH STATUS'** : Todas las pruebas muestran que o bien entraron en ese año en la lista, en cuyo caso aun no se conoce su salud financiera o tienen un solo registro.
# > riquitos_forbes_13_23[riquitos_forbes_13_23.full_name == 'Yogesh Kothari']
#
# También hay algunos que en el primer registro no tienen nada y luego ya estan completos,de modo que lo sustituiremos por "no informado"
#
# > riquitos_forbes_13_23['wealth_status'].fillna('No informado',inplace=True) # para mantener el campo en el dataset original
#
# ### **TABLA DE VARIABLES QUE USAREMOS FINALMENTE**
# 1. YEAR, año de recogida del dato en forbes, dato int64
# 2. RANK,  Cada individuo en la lista tiene asignado un número de rango específico según el valor de su patrimonio neto en comparación con los demás en la misma lista, dato float64
# 3. NET_WORTH, PATRIMONIO NETO, ACTIVOS-PASIVOS, dato object, necesita transformación a float64
# 4. FULL NAME,  NOMBRE Y APELLIDO , dato object
# 5. BIRTH DAY, dia de nacimiento, dato object, necesita transformación a datetime
# 6. AGE, edad, dato object, necesita transformación a float64 o int64
# 7. GENDER, genero, dato object
# 8. COUNTRY_OF_CITIZEN , pais de ciudadania, dato object
# 9. BUSSINESS _CATEGORY, categoría de negocio (TECNOLOGIA, FINANZAS..) MAS GENERAL, dato object
# 10. BUSINESS_INDUSTRIES (SOLO LA USARE PARA LA PARTE TÉCNOLOGICA DE MI HIPÓTESIS), subdivisiones más detalladas dentro de una categoría de negocio. Por ejemplo, si la categoría de negocio es "Tecnología", las industrias de negocios podrían incluir software, hardware, servicios en la nube, redes sociales, etc, dato object.
# 11. SELF_MADE, "Self-made" se refiere a personas que han acumulado su riqueza y éxito por sus propios esfuerzos y habilidades, en lugar de heredarla, dato objeto, REVISARLO SI HAY PROBLEMAS PORQUE ES UN BOOLEANO, quizas necesita transformación
# 12. WEALTH STATUS , SALUD FINANCIERA, dato object
#
# y podemos pasar a la siguiente fase.
# Ahora que tenemos las variables de ambos Dataframe definidas, nos quedan dos tareas que hacer antes de pasar a los análisis: confirmar el formato de los datos y estudiar los outliers.
# EMPEZAMOS CON NET WORTH, HAY QUE CAMBIARLA, PORQUE LA B IMPIDE QUE SE TRANSFORME, Y DEBE SER DOBLE, PORQUE EL DATO ES OBJETO NO CADENA
# > riquitos_forbes_13_23['net_worth'] = riquitos_forbes_13_23['net_worth'].astype(str).str.replace("B", "").astype(float)
#
# Luego, birth day, para pasarlo a datetime, OJOO! como hicimos el relleno de nulos antes, ahora da error el DATO DESCONOCIDO por el que los sustituimos pues ese dato sustituto es cadena y obviamente no pueden cambiarse a datetime. NOTA PARA EL FUTURO!! cambio de datos ANTES DE RELLENO DE NULOS!
# Hay que o bien volver cambiar a NAN de nuevo y luego volver a hacer el cambio a DESCONOCIDO o cambiarlo arriba
#
# > Reemplazar 'DESCONOCIDO' por NaN
# riquitos_forbes_13_23['birth_date'] = riquitos_forbes_13_23['birth_date'].replace('DESCONOCIDO', pd.NaT)
#
# > Convertir a datetime
# riquitos_forbes_13_23['birth_date'] = pd.to_datetime(riquitos_forbes_13_23['birth_date'], errors='coerce')
#
# >>NOTA EXTRA PARA EL FUTURO Y FEEDBACK, CUBRIR LOS NULOS TRAS LA TRANFORMACION!! Al cambiar ya la columna a datetime, YA NO NOS SIRVE DESCONOCIDA como SUSTITUTO DEL NAN, tiene que ser un dato datetime, PERO SI ELEGIMOS UN DATO MUY ALTO O MUY BAJO, NOS CAMBIARÍA LA MEDIA Y NOS CREARÍA OUTLIERS QUE FALSEARÍAN EL DATO!!!
# LO MISMO PASARA EN LA COLUMNA EDAD, NO PODEMOS PONER 0, NI 100 NI NINGUN DATO INVENTADO PORQUE LOS DATOS NO SERÍAN REALES.
# DE MODO QUE, A PESAR DE TODO LO QUE HEMOS HECHO ANTERIORMENTE, HAY QUE ELIMINAR LAS FILAS NULAS EN EDAD Y FECHA DE NACIMIENTO.
#
# Ahora haremos lo mismo con age.
# > riquitos_forbes_13_23['age'] = riquitos_forbes_13_23['age'].replace('DESCONOCIDO', pd.NaT)
# riquitos_forbes_13_23['age'] = pd.to_numeric(riquitos_forbes_13_23['age'], errors='coerce')
#
# Finalmente, por el cambio de dato, tendremos que desprendernos de los 614 registros de todas las columnas que son nulas en birth day y age. Eliminamos los nulos
# > riquitos_forbes_13_23.dropna(subset=['birth_date','age'], inplace=True)
#
# YA TENDRIAMOS POR FIN LIMPIAS LAS TABLAS, LOS NULOS ELIMINADOS, Y SOLO HABRÍA QUE EMPEZAR A SACAR ESTADÍSTICOS.
#
#
# ### 3. Analysis
# La limpieza de datos ocupa la mayor parte del tiempo, a partir de este momento nos queda sacar estadísticos, gráficas, analizar los resultados y contrastarlos con las hipótesis iniciales.
#
# 1. **Análisis univariante**: (TODOS ESTÁN EN LOS NOTEBOOKS CORRESPONDIENTES DE FORBES Y WEALTH SOURCE) en este apartado se pretende describir la variable mediante diferentes estadísticos, así como graficando su función de distribución para ver la forma, asimetría, centralidad y dispersión de la misma.
#
#     - Estadísticos de centralidad: media, mediana, moda, cuartiles y percentiles
#
#     - Estadísticos de dispersión: varianza, desviación estándar, rango, mínimo y máximo
#
#     - Gráficas: Tablas de frecuencias, histogramas, función densidad de probabilidad, diagrama de caja, diagrama de barras, violin plot, swarm plot.
#
#     - Outliers:  En el caso de Data Analysis no debemos eliminar los outliers, sino que resulta interesante destacar outliers y por qué de los mismos. Podremos visualizarlo más fácilmente por separado con un histograma (si es cualitativa la variable); con un boxplot o scatter plot si es cuantitativa, o con cualquier otra gráfica que veamos adecuada.
#
# Empezamos con la tabla de Wealth_source. Creamos las gráficas para todas las variables y además los estadísticos para las que son cuantitativas.
# Nos encontramos con algunos problemas, sobre todo en la representación de las cualitativas, PUES AL TENER MUCHOS VALORES ÚNICOS, COMO EN LA VARIABLE NAME, SE EMBORRONA LA GRÁFICA. Filtramos los primeros 20, pero tampoco es muy útil. Haremos más gráficas con agrupaciones, para que se vean mas claras.
# También en la variable annual_income encontramos que las gráficas se ven mal, porque HAY MUCHA DISPERSIÓN EN LOS DATOS (el máximo corresponde a 5650200000 y el mínimo 18000000)
# En COMPANY, TAMBIEN CATEGORIcA, DATO OBJECT, acamos una conclusión curiosa, LOS NULL TRANSFORMADOS POR NOSOTROS EN TAREAS ANTERIORES SON EL MÁXIMO VALOR EN RECUENTO.
# A la hora de representar, LO TENDRE EN CUENTA, PUES IGUAL ES MEJOR ELIMINARLOS DE LA ECUACION SI ME VAN A ESTROPEAR LOS DATOS PARA LAS GRAFICAS
#
# Algo similar nos ocurre con la tabla de Forbes.
# Algunas de las variables cualitativas, como FULL NAME o COUNTRY_OF_CITIZENSHIP, tienen demasiados valores únicos para representar.
# De igual modo, en la variable RANK PROBAMOS VARIOS AÑOS, Y EN TODOS ESTÁN ORGANIZADOS DESDE 1 HASTA 2500 O SEMEJANTE, PERO COMPROBAMOS ALGO, HAY ALGUNAS POSICIONES COMPARTIDAS! EJEMPLO, 2578 EN EL AÑO 2022 HAY MAS DE UN INDIVIDUO, SI TIENEN EL MISMO NET_WORTH. Dado que van a aparecer por cada año el mismo valor, una o varias veces, no tiene sentido representar graficamente AUN.
# Con net_worth pasa más o menos igual, SI NO PONEMOS UN AÑO O UN INDIVIDUO O AGRUPAMOS POR ALGO MAS, NO TENEMOS DATOS CORRECTOS, PORQUE EL NETWORTH DE ALGUNOS INDIVIDUOS VA CAMBIANDO DEPENDIENDO DEL AÑO EN QUE SE MIRE.
# En GENDER, como en el anterior,TENEMOS QUE ELIMINAR LOS QUE NO SEAN MASCULINO O FEMENINO PARA REPRESENTAR.
# Solo para la gráfica, eliminamos INDETERMINADO (como llenamos los nulos anteriormente en esta columna).
# Algo que nos ha hecho modificar las variables Y ELIMINAR LA COLUMNA BUSINESS_INDUSTRIES. Al analizar business_category y business_industries, nos damos cuenta de que finalmente business_industries, que al ser más concreta que business_category la dejamos para poder filtrar en tecnología nada más (para nuestra hipótesis), NO NOS APORTA INFORMACIÓN NECESARIA, ASI QUE LA ELIMINAMOS
# Con wealth_status, nos sucede algo. Tras hacer la gráfica, TENEMOS QUE TENER ALGO EN CUENTA, NO DA MUCHA INFORMACION, PORQUE EL AUMENTO O DISMINUCION DE LA FORTUNA SIN TENER NINGUN AÑO O INDIVIDUO SOBRE EL QUE VERLO, NO SIRVE DE MUCHO.
# Para usar esta variable, tendremos que tener en cuenta esos otros factores para sacar información REAL.
#
#
# 2. **Análisis multivariante Y bivariante**:
# Empezando por el Dataset de Forbes, con todos los análisis univariantes hechos, podemos pasar a la relación entre variables. PRIMERO CREAMOS UN MAPA DE CALOR PARA VER LA CORRELACION ENTRE TODAS (aunque solo podemos hacerlo con variables númericas, claramente)
# > sns.heatmap(riquitos_forbes_13_23.corr(numeric_only=True), annot=True, cmap='YlGnBu', cbar=True)
#
# También nos serviremos de un grid de gráficas con pairplot, sólo con las columnas numéricas.
# > RIQUITOS_NUMERICOS = riquitos_forbes_13_23.select_dtypes(include=['float64', 'int64'])
# sns.pairplot(RIQUITOS_NUMERICOS)
#
# No parece que las varibles numéricas de nuestro Dataframe estén muy relacionadas, ni positiva ni negativamente (ninguno supera los 0,67 o -0,67) aunque si que podemos ver una relación negativa más marcada entre RANK y NETWORTH y una ligeramente positiva entre YEAR y RANK(aunque no muy clara)
# HAREMOS UN SCATTER PLOT PARA LA RELACION DE RANK Y NET_WORTH
# Tra hacerlo vemos que A MAS BAJO EL NETWORTH MAS ALTO ESTÁN EN EL RANKING, PERO NO SE VE TOTALMENTE BIEN REPRESENTADA pues
# DEBERIAMOS TENER EN CUENTA TAMBIÉN EL AÑO EN LA COMPARACIÓN, ¡¡¡PUES EL RANKING PUEDE IR CAMBIANDO CADA AÑO!!!
#
# Con respecto a la segunda relación, entre YEAR Y RANK, CONOCIENDO NUESTRAS VARIABLES TRAS SU ESTUDIO INDIVIDUAL, LA RELACION ENTRE YEAR Y RANK NO TIENE SENTIDO, pues RANK se reinicia y empieza en 1 cada año (al ser un ranking relacionado con net_worth (patrimonio del individuo), puede haber personas diferentes en la posición uno cada añopor lo que no podemos decir que a más o menos años hay más o menos RANKING)
#
# Con el segundo dataset, el de Wealth_source, hacemos lo mismo, mapa de calor (heatmap) y graficas conjuntas (pairplots)
# No encontramos muchas relaciones significativas entres las variables, EXCEPTO LA RELACIÓN INVERSAMENTE PROPORCIONAL ENTRE AÑO DE NACIMIENTO Y EDAD, POR SUPUESTO, pues a mayor año de nacimiento...menor edad.
# PODRÍA ELIMINAR UNA DE LAS DOS, pero hay hipótesis distintas para las que me sirven las dos, de modo que las mantengo.
#
# >>UNA VEZ ANALIZADAS LAS VARIABLES DE MANERA INDIVIDUAL Y COLECTIVA, PODEMOS EMPEZAR A REVISAR LAS HIPÓTESIS, donde tendremos que acudir a agrupaciones entre variables, realizar más análisis bivariantes, no sólo con las numéricas para extraer los datos que necesitamos
#
# ### 4. Resultados
# 1. **Contraste con hipótesis**: Con respecto a las hipótesis planteadas, nos hemos encontrado con varias dificultades tanto en los dos Dataframe (errores en los datos, columnas no actualizadas...) como en las propias cuestiones planteadas (por ejemplo, preparé un Dataframe para poder ver el PIB DE LOS PAÍSES Y COMPARARLO CON SUS MILLONARIOS y tras limpiarlo y cuando fui a usarlo, vimos que estaba en variación con respecto al año anterior, no en valores absolutos, por lo que no pudimos usarlo por falta de tiempo para la transformación, aunque lo guardamos para poder incluirlo en un futuro, con más tiempo) para encontrar respuestas.
# Sin embargo, sacamos varias conclusiones (que están más especificadas en los notebooks correspondientes):
#
# HIPOTESIS-TOTAL = "La edad y el género de un billonario influye en la probabilidad de tener una empresa tecnológica. La preferencia por sectores tecnológicos se relaciona con la edad del billonario y con su género"
# - Primero hicimos una introducción para ver como había evolucionado la tecnología con los años (su codigo está en el notebook prueba millonatios 20-yrs)
# ![image.png](attachment:image.png)
# y vimos que la tecnología está en alza. Luego ya fuimos a concretar las dos subhipótesis:
#
# HIPOTESIS1 = "Los billonarios más jóvenes podrían tener una mayor probabilidad de tener empresas tecnológicas debido a su familiaridad con las tendencias actuales."
#
# Desde el Dataframe prueba 1997-2023, hicimos un filtro solo con los tecnologicos, y luego UN RANGO DE EDAD
# ![image-2.png](attachment:image-2.png)
# POR ESTA PRIMERA GRAFICA,  VEMOS QUE LOS MILLONARIOS EN EL SECTOR TECNOLOGICO TIENEN UNA MEDIA DE EDAD ENTRE 41-50 AÑOS.
# Dando una vuelta mas, puede ser que haya mas millonarios de otras edades porque prosperan a edad mas tardia Y PORQUE HAY MAS, pero prefiero dar informacion de los millonarios entre 20 y 40 años y las industrias en las que invierte mas,
# PARA VER SI ESTAN EMPEZANDO A INVERTIR MAS EN TECNOLOGIA
# Filtro los millonarios entre 20 y 40 años,
# ![image-3.png](attachment:image-3.png)
# De este modo, si podemos ver de forma mas clara que los millonarios más jovenes invierten la gran mayoria en tecnologia.
# PERO MAS QUE LOS MAYORES DE 45 AÑOS, POR EJEMPLO?
# Filtramos ahora por los mayores de 45, de 45 a 60 años
# ![image-4.png](attachment:image-4.png)
# Podemos ver que, si bien hay muchos mas individuos tecnologicos que en la anterior, las industrias en las que invierten
# SON BASTANTE MAS DISPARES QUE EN LA EDAD DE 20 A 40, que están mas centrados en la tecnologia
# DE MODO QUE EN UN PRIMER MOMENTO, DAMOS POR BUENA LA HIPOTESIS DE LA TECNOLOGIA y la edad.
#
#
# HIPOTESIS2 = "Podría haber diferencias en la participación en industrias tecnológicas emergentes entre mujeres y hombres billonarios, siendo mayores las de los hombres"
# ![image-5.png](attachment:image-5.png)
# En la proporción de hombres y mujeres, obviamente estamos en desventaja, 90 a 10, PERO TAMBIÉN HAY MENOS MUJERES MILLONARIAS, DE MODO QUE PARA TENER UNA REFERENCIA MAS CLARA, HAREMOS UNA GRAFICA CON LA MUJERES QUE SE HAN CENTRADO EN INDUSTRIAS TECNOLOGICAS Y LAS QUE NO
# ![image-6.png](attachment:image-6.png)
# 53 mujeres de 450 MILLONARIAS invirtieron en tecnologia, UN 11,7 POR CIENTO.
#
# AHORA LOS HOMBRES
# ![image-7.png](attachment:image-7.png)
# 731 hombres de 3215 MILLONARIOS invirtieron en tecnologia, un 22,73 por ciento.
# DE MODO QUE SE CONFIRMA LA HIPOTESIS PRINCIPAL, Y LOS HOMBRES PARTICIPAN EN EMPRESAS TECNOLÓGICAS MÁS QUE LAS MUJERES
#
# ### Hipotesis_2 = "Algunas industrias, como las tecnológicas o las de finanzas e inversiones, pueden tener una concentración mayor de multimillonarios"
# ![image-8.png](attachment:image-8.png)
#
# HIPOTESIS CONFIRMADA EN EL CASO DE LA TECNOLOGÍA, PERO NO EN LAS FINANZAS, QUE CAEN AL SEXTO U OCTAVO PUESTO.
# SIN EMBARGO, CUANDO HEMOS VISTO LAS DEL AÑO 2023, SI QUE NOS HA SALIDO FINANZAS COMO LA CATEGORIA QUE MÁS MILLONARIOS MANTIENEN EN LA LISTA
# ![image-9.png](attachment:image-9.png)
#
# Para tener una referencia más clara y PARA ASEGURARNOS DE QUE ESTAMOS CONTANDO CORRECTAMENTE (PUES NOS PREOCUPA QUE SE ESTEN CONTANDO EN AÑOS DISTINTOS LOS NOMBRES IGUALES COMO OTRA REFERENCIA)
# Eliminamos duplicados basados en la columna 'full_name' y creamos el gráfico
# ![image-10.png](attachment:image-10.png) EN EL NOTEBOOK
#
# HIPOTESIS CONFIRMADA EN EL CASO DE LA TECNOLOGÍA, PERO NO EN LAS FINANZAS, QUE CAEN AL CUARTO PUESTO
#
# ### Hipotesis_3 = "La cantidad de mujeres billonarias que han alcanzado su fortuna a una edad temprana es menor de las que lo han logrado más tarde en la vida y la edad de inicio y la nacionalidad podría influir en la elección de la industria en la que las mujeres billonarias tienen éxito."
# Filtramos solo a las mujeres (gendeer=Female) y creamos un dataframe
# y ahora, tratamos de responder a nuestras preguntas, LAS MILLONARIAS TRIUNFAN A EDAD MÁS TEMPRANA O NO?
# print(mujeres_millonarias.age.mean()) # La edad media son 59 años, no parece que triunfen jovenes, pero vamos a ver las que tienen menos edad
# CONSIDEREMOS QUE TRIUNFAR A EDAD JOVEN SEA HACERSE MILLONARIA ANTES DE LOS 40 (AUN ESTOY A TIEMPO)
# print(len(mujeres_millonarias[mujeres_millonarias.age < 40])) # hay 43 mujeres de las 503 millonarias antes de los 40, es un porcentaje pequeño
# y si disminuimos a 34 (mi edad)
# print(len(mujeres_millonarias[mujeres_millonarias.age < 34])) # SOLO 19!! Tengo esperanzas
#
# ![image-11.png](attachment:image-11.png) REPRESENTADO
#
# CONFIRMACIÓN A LA PRIMERA CUESTIÓN DE LA HIPOTESIS 3, AFIRMATIVA, LAS MUJERES TRIUNFAN A MAYOR EDAD
#
# Con respecto a  ¿LA ELECCION DE LA INDUSTRIA DEPENDE DE LA EDAD? Primero, veremos en que industrias están presentes
# >mujeres_millonarias.business_category.value_counts() # sobre todo en manufacturing, Tecnologia (BIIIEN) Y FASHION RETAIL
#
# Ahora, me toca agrupar por edad e industria y contar la cantidad de multimillonarias en cada grupo
# >millonarias_agrupadas = mujeres_millonarias.groupby(['age', 'business_category']).size().reset_index(name='count')
# Y CREAMOS LA VISUALIZACION
# ![image-12.png](attachment:image-12.png)
# NOTA A RECORDAR, ME HA DADO PROBLEMAS A LA HORA DE AGRUPAR, ME EMPEÑABA EN AGRUPAR SOBRE AGE Y LUEGO PONER ENTRE CORCHETES BUSINESS CATEGORY. TENERLO CLARO PARA LAS PROXIMAS VECES.
#
# PODEMOS VISUALIZAR LA MEDIA DE EDAD POR INDUSTRIA Y VEMOS QUE, POR EJEMPLO, LAS CHICAS JOVENES SON MAS COMUNES EN DIVERsIFIED, MEDIA & ENTERTAIMENT Y RETAIL&ECOMMERCE.
# MIENTRAS QUE LAS MÁS MAYORES ESTÁN MAS REPRESENTADAS EN TODOS LOS SECTORES. Hay algunos sectores como manufacturing, el más común, que tiene representaciones de casi todas las edades.
# COMO RESPUESTA A NUESTRA HIPÓTESIS, ES BASTANTE MÁS VISIBLE QUE LAS MILLONARIAS JÓVENES INVIERTEN EN SECTORES MÁS ESPECIALIZADOS QUE LAS MAYORES, PERO NO HAY UNA RESPUESTA CLARA.
# RECICLARE ESTA GRÁFICA PARA LA RESPUESTA A MI HIPOTESIS PRINCIPAL, SOLO CON TECNOLOGIA!
#
# Ahora por categoria de negocio y nacionalidad
# millonarias_agrupadas2 = mujeres_millonarias.groupby(['business_category', 'country_of_citizenship']).size().reset_index(name='count')
# Y CREAMOS LA VISUALIZACION
# ![image-13.png](attachment:image-13.png)
#
# Vemos una variedad en los países, por lo que no podemos asegurar nuestra hipótesis de que la nacionalidad tiene alguna relación con la industria de la millonaria
#
# ### Hipotesis_4 = "Los millonarios en España han aumentado en la última década"
# Creamos un dataframe solo con los millonarios españoles
# ![image-14.png](attachment:image-14.png)
#
# AUNQUE BIEN ES CIERTO QUE DESDE 2012 HAN IDO EN AUMENTO, HAY BASTANTES FLUCTUACIONES DE MODO QUE NO, NO ASEGURAMOS QUE LOS MILLONARIOS HAN AUMENTADO EN ESPAÑA, AUNQUE BIEN ES CIERTO QUE AQUI NO TENEMOS
# A TODOS LOS MILLONARIOS, SOLO A LOS QUE SALEN EN FORBES QUE TIENEN FORTUNAS POR ENCIMA DE MIL MILLONES,
# DE MODO QUE NO SERÍA TAMPOCO MUY ÚTIL ESTA VALIDACIÓN
#
# FINALMENTE HE ELIMINADO UNA HIPOTESIS
# ### HIPOTESIS :"El PIB de un país repercute de manera positiva en el número de millonarios del mismo,
# a mayor PIB, MAYOR CONCENTRACIÓN DE MILLONARIOS. Queria servirme del dataframe ya limpio PIB ANUAL Y POR PAIS, TRAS DESCUBRIR LOS 10 PAISES CON MAS MILLONARIOS, pero en mi dataframe PIB ANUAL, LO QUE SE ESTUDIA ES COMO HA EVOLUCIONADO EL PIB DE UN AÑO A OTRO, NO LA CANTIDAD TOTAL, POR LO QUE FINALMENTE NO ME SERVIRÍA PARA RESPALDAR NINGUNA HIPÓTESIS
# paises_millonarios = forbes_sin_duplicados['country_of_citizenship'].value_counts().reset_index().head(10)
# ![image-15.png](attachment:image-15.png)
#
# ESPAÑA NO ESTA ENTRE ELLOS
#
# ### Hipotesis_5 = "Orígenes de la Riqueza: HEREDADA O GENERADA? Hipótesis: Los multimillonarios pueden haber acumulado riqueza a través de una herencia o por emprendimiento, PERO SON MAS COMUNES LOS MILLONARIOS EMPRENDEDORES"
# Usamos la columna SELF MADE. Si es True, es HECHO A SI MISMO, NO HEREDADA.
# Para esta hipotesis, tambien uso el dataframe con los duplicados eliminados
# > forbes_sin_duplicados.self_made.value_counts()
# PUEDO USAR UN COUNTPLOT DE SEABORN, QUE HACE EL CONTEO DIRECTAMENTE
# ![image-16.png](attachment:image-16.png)
# COMO RESPUESTA A LA HIPOTESIS, SI, SON MAS COMUNES LOS EMPRENDEDORES O HECHOS A UNO MISMO QUE LOS QUE HAN HEREDADO LA RIQUEZA
#
# ### Hipotesis_6 = "Eventos económicos significativos, como el COVID, podrían influir en la tasa de crecimiento de la fortuna de los billonarios"
# Nos servimos del dataset [Title](<../notebooks/datasets usados/variacion_del_numero_de_millonarios_por_paises (1).csv>)
#
# ![image-17.png](attachment:image-17.png)
#
#
# Y, AUNQUE HAY ALGUNOS PAISES COMO ALEMANIA, PAISES BAJOS, ITALIA Y SOBRE TODO JAPON QUE SE VIERON PERJUDICADOS DE 2020 A 2021, HAY OTROS, COMO BELGICA, AUSTRIA, INDIA Y SOBRE TODO TAIWAN (curioso que fuera despues del covid) QUE SE VIERON BENEFICIADOS. Si embargo, para poder dar por buena una hipotesis de este calibre, sería necesario ANALIZAR MÁS EVENTOS SIGNIFICATIVOS, NO SOLO UNO.
#
# ### Hipotesis_7 = "Aquellos que aparecen en la lista de billonarios de manera consistente (durante mas años seguidos) podrían tener fortunas más estables"
# PARA PODER VISUALIZARLO, HAY QUE COGER EL DATASET FILTRADO ORIGINAL
# riquitos_forbes_13_23.full_name.value_counts()
# ESTUDIAMOS EL TOP_THREE DE LOS QUE MAS APARECEN EN EL RANKING.
# El que mas veces aparece, APARECE INCLUSO DOS VECES POR AÑO, PORQUE TIENE DOS EMPRESAS, TECNOLOGIA Y FASHION RETAIL, ES ROBERT MILLER
# riquitos_forbes_13_23[riquitos_forbes_13_23.full_name == 'Robert Miller']
# SIN EMBARGO, SE VE QUE EN LOS ULTIMOS AÑO SU FORTUNA ESTA DISMINUYENDO.
# Hacemos lo mismo con Li Li y con Oleg Deripaska
#
# SIN EMBARGO,NO TIENEN UNA FORTUNA MÁS ESTABLE. DE HECHO, su fortuna ha ido disminuyendo casi todos los años desde 2012 hasta ahora de modo que no podemos reespaldarnos en estos datos para afirmar la hipotesis anterior. SEGUIR APARECIENDO EN EL RANKING NO GARANTIZA QUE TU FORTUNA SEA MAS ESTABLE.
#
# ### Hipotesis_8 (LOCA) = "Hipótesis del horóscopo chino de Wealth-X, las personas nacidas en el año del dragón (1940, 1952, 1964, 1976, 1988, 2000, 2012) tienen más probabilidades de acumular riqueza. ¿El horóscopo chino puede predecir la fortuna financiera?"
# Para la última hipotesis, HIPOTESIS DEL HOROSCOP CHINO tenemos que ver LOS MILLONARIOS NACIDOS EN QUE AÑO SON MAS REPRESENTATIVOS
# > millonetis_Global_Wealth_Source_sinduplicados.birth_year.value_counts().head(10)
#  y comprobar si son de los años 1940, 1952, 1964, 1976, 1988, 2000, 2012
# dentro de los diez primeros SE CUMPLE EL PRIMER AÑO 1964 y 1952!
# SIN EMBARGO, 1950 ES EL AÑO DEL TIGRE, Y 1954 ES EL AÑO DEL CABALLO
#
# PARA EVITAR EN ESTA REPRESENTACION LOS ESPACIOS VACIOS (años que no ha nacido ningun millonario) que tenemos con un histograma, CREAMOS UN PIE CHART con los 20 primeros años
# top_cumpleaños = millonetis_Global_Wealth_Source_sinduplicados['birth_year'].value_counts().head(20).reset_index()
# top_cumpleaños.columns = ['Año de Nacimiento', 'Cantidad']
# ![image-18.png](attachment:image-18.png)
#
# ES UNA HIPOTESIS DIVERTIDA, AUNQUE SIENDO SINCEROS, QUE 2 DE 10 DE LOS 10 PRIMEROS PUESTOS EN AÑOS DE MILLONARIOS PERTENEZCAN AL AÑO DEL DRAGON DA QUE PENSAR.
#
# 2. **Plan de acción**: ¿qué vamos a hacer en función de los resultados? Pues los resultados no son muy halagüeños para mi idea principal, las mujeres no invierten mucho en la industria millonaria, un 11'7 por ciento del total. Aunque hay que reconocer que con respecto a la primera pregunta, LA EDAD DE LOS MILLONARIOS, sí que estoy aún en un rango que me da esperanzas, pues confirmamos que los jóvenes están invirtiendo de manera más global en tecnología y que el groso de millonarios tecnológicos ronda los 50 años (tengo tiempo). La tecnología es un sector en alza, y tenemos oportunidades infinitas SI ESTAMOS DISPUESTOS A LUCHAR POR ELLO.
